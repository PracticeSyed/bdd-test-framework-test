# %%
from IPython.display import HTML

with open('tests/bdd/reports/report_20260622_054506.html', 'r') as f:
    html_content = f.read()

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html><head><title>Test Report</title><style>
# body{font-family:Arial;margin:20px;background:#f5f5f5}
# .header{background:#2196F3;color:white;padding:20px;border-radius:5px}
# .stats{display:flex;gap:20px;margin:20px 0}
# .stat{background:white;padding:15px;border-radius:5px;flex:1;text-align:center}
# .passed{color:#4CAF50;font-size:24px;font-weight:bold}
# .failed{color:#f44336;font-size:24px;font-weight:bold}
# .scenario{background:white;margin:10px 0;padding:15px;border-radius:5px;border-left:4px solid #4CAF50}
# .scenario.fail{border-left-color:#f44336}
# </style></head><body>
# <div class="header"><h1>🧪 Test Report</h1><p>20260622_054506</p></div>
# <div class="stats">
# <div class="stat"><div class="passed">4</div>Passed</div>
# <div class="stat"><div class="failed">0</div>Failed</div>
# <div class="stat"><div>4</div>Total</div>
# </div>
# ...
